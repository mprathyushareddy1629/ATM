# %% [markdown]
# # ATM

# %% [markdown]
# #####

# %%
#ATM 
#Authored by Prathyusha
#Date: 18-02-2023
#version:0.4




print("****WELCOME****")


#function to show the current balance of the account

def balance(): 
    print("Your current balance is :",user['user_bal'],"Rs\n")

#function to withdraw money from the account 

def withdraw(): 
    amount=int(input("Enter the amount you want to withdraw:")) #entering the amount to withdraw
    if amount%100!=0:     #making sure amount is in either 100's,200's,500's,2000's for withdrawing cash
         print("Enter amount in 100's,200's,500's or 2000's")
    else:
        if amount < user['user_bal']:   #if amount is less than the balance then intiating withdrawal
            con=str(input("withdrawing amount...\n Confirm? Y/N\n"))
            if con=='Y' or con=='y':    #confirming to proceed with the transaction
                user['user_bal']=user['user_bal']-amount
                print("Loading...\n")
                print("successfully withdrawn the amount of  ",amount) #withdrawing amount
                print("your current balance is : ",user['user_bal'])   #showing current balance
            else:
                print("Withdrawing cancelled..") #cancelling the process
        else:
            print("Insufficient balance ") #if withdrawal amount is more than the balance
            
            
#function to deposit money from the account
    
def deposit():
    print("Loading cash deposit...")
    amount=int(input("Enter amount you have to deposit :"))
    if amount%100!=0:  #making sure amount to be in 100's,200's,500's or 2000's for depositing cash
         print("Enter amount in 100's,200's,500's or 2000's")
    else:
        print("Depositing amount of Rs.",amount)
        con=str(input("confirm deposit?? Y/N")) #confirming deposit
        if con=='y' or con=='Y':
            print("Load cash") #taking cash 
            print("Amount deposited")
            print("current balance is :",user['user_bal']+amount) #depositing and adding to bank account
        else:
            print("deposit cancelled")
            
            

#asking the user for what operation to perform

print("what operation do you have to perform?")
choice={1:'check balance',2:'withdraw cash',3:'deposit money',4:'exit'} #choice of operations
print(choice)
c=int(input()) #choosing the operation to be performed
if c in (1,2,3):
    input_pin = int(input("Please enter your 4-digit PIN > ")) #Entering the pin
    if input_pin ==user['user_pin']:  #checking if pin is valid.
        print("Account auhtorized!\n\n")
        if c==1:
            balance() #initiating balance function
        elif c==2:
            withdraw() #initiating withdraw function
        elif c==3:
            deposit() #intiating deposit function
    else:                       
        print("PIN incorrect")  #if pin is incorrect
               
elif c==4:                
    print("See you again!!")      #if 4th operation is choosed

    
else:
    print("Invalid choice")  #if the selected choice is invalid
    
    


    
#dictionary holding pin and balance of the account holder
user={'user_pin':7890,'user_bal':8000}
# Out:
# ****WELCOME****
# what operation do you have to perform?
# {1: 'check balance', 2: 'withdraw cash', 3: 'deposit money', 4: 'exit'}
# 2
# Please enter your 4-digit PIN > 7890
# Account auhtorized!
#
#
# Enter the amount you want to withdraw:500
# withdrawing amount...
#  Confirm? Y/N
# y
# Loading...
#
# successfully withdrawn the amount of   500
# your current balance is :  7500
